# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt

from webAPI.model_utils import fish_model
from webAPI.img_preprocess import preprocess_image
from webAPI.main import run_model

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = preprocess_image('webAPI/test_images/Abbor.jpeg')
m = fish_model()
m.load_freshwater_model('webAPI/model_files/Freshwater_model')
plt.imshow(img[0,:,:,:])

# %%
m.predict_for_image(img)
#m.predictions

# %%
for i, el in enumerate(m.top_fish_predictions):
    print('%s: %.4f' % (el, m.top_fish_predictions_probs[i]))
# Out:
# Sorv: 0.2823
# Gjors: 0.1664
# Steinsmett: 0.1319
# Abbor: 0.1038
# Flire: 0.0800
